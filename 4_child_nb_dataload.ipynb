# %%
import requests
url = "https://public.tableau.com/app/sample-data/mobile_os_usage.csv"  # replace with your file URL
response = requests.get(url)
file_content = response.text

print(file_content)

# %%
dbutils.fs.put("///Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",file_content,overwrite=True)
